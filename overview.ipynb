# %%
import pandas as pd
import os

# %%
train = pd.read_csv(os.path.join("data/processed/","rating_train_v2.csv"))

# %%
train.head(10)
# Out:
#    user_id  anime_id  rating  user_mean_rating  user_median_rating  \
# 0        1      8074    10.0         10.000000                10.0
# 1        1     11617    10.0         10.000000                10.0
# 2        1     11757    10.0         10.000000                10.0
# 3        1     15451    10.0         10.000000                10.0
# 4        2     11771    10.0         10.000000                10.0
# 5        3        20     8.0          7.565217                 7.0
# 6        3       154     6.0          7.565217                 7.0
# 7        3       170     9.0          7.565217                 7.0
# 8        3       199    10.0          7.565217                 7.0
# 9        3       225     9.0          7.565217                 7.0
#
#    user_rating_count  user_rating_std  engagement_percentile  \
# 0                  4         0.000000              16.036183
# 1                  4         0.000000              16.036183
# 2                  4         0.000000              16.036183
# 3                  4         0.000000              16.036183
# 4                  1         0.000000               7.535877
# 5                 92         1.549933              70.892335
# 6                 92         1.549933              70.892335
# 7                 92         1.549933              70.892335
# 8                 92         1.549933              70.892335
# 9                 92         1.549933              70.892335
#
#    normalized_rating                             top_genres  genre_diversity
# 0           0.000000        ['Comedy', 'Romance', 'Action']               30
# 1           0.000000        ['Comedy', 'Romance', 'Action']               30
# 2           0.000000        ['Comedy', 'Romance', 'Action']               30
# 3           0.000000        ['Comedy', 'Romance', 'Action']               30
# 4           0.000000  ['Comedy', 'School', 'Slice of Life']                6
# 5           0.280517     ['Action', 'Fantasy', 'Adventure']               32
# 6          -1.009861     ['Action', 'Fantasy', 'Adventure']               32
# 7           0.925706     ['Action', 'Fantasy', 'Adventure']               32
# 8           1.570895     ['Action', 'Fantasy', 'Adventure']               32
# 9           0.925706     ['Action', 'Fantasy', 'Adventure']               32

# %%
anime = train = pd.read_csv(os.path.join("data/processed/","anime_features_normalized.csv"))

# %%
anime.head(10)
# Out:
#    anime_id                                               name  episodes  \
# 0     32281                                     Kimi no Na wa.  0.000000
# 1      5114                   Fullmetal Alchemist: Brotherhood  0.034673
# 2     28977                                           Gintama°  0.027518
# 3      9253                                        Steins;Gate  0.012658
# 4      9969                                      Gintama&#039;  0.027518
# 5     32935  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...  0.004953
# 6     11061                             Hunter x Hunter (2011)  0.080903
# 7       820                               Ginga Eiyuu Densetsu  0.059989
# 8     15335  Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...  0.000000
# 9     15417                           Gintama&#039;: Enchousen  0.006604
#
#    rating   members  rating_count  user_avg_rating  user_median_rating  \
# 0    9.37  0.197872      0.055897         0.942631                 1.0
# 1    9.26  0.782770      0.624657         0.932274                 1.0
# 2    9.25  0.112689      0.035231         0.944949                 1.0
# 3    9.17  0.664325      0.490163         0.926133                 1.0
# 4    9.16  0.149186      0.093366         0.927255                 1.0
# 5    9.15  0.092065      0.031342         0.917148                 0.9
# 6    9.13  0.420007      0.217972         0.923459                 1.0
# 7    9.11  0.079567      0.022954         0.938979                 1.0
# 8    9.10  0.071534      0.064184         0.919143                 1.0
# 9    9.11  0.079991      0.064489         0.920226                 1.0
#
#    user_rating_std  popularity_percentile  ...  Vampire  Yaoi  Yuri  \
# 0         0.138814               0.914643  ...        0     0     0
# 1         0.147149               0.999286  ...        0     0     0
# 2         0.149327               0.876875  ...        0     0     0
# 3         0.159023               0.998304  ...        0     0     0
# 4         0.164665               0.949732  ...        0     0     0
# 5         0.150199               0.867054  ...        0     0     0
# 6         0.152814               0.986339  ...        0     0     0
# 7         0.160527               0.835893  ...        0     0     0
# 8         0.171769               0.924375  ...        0     0     0
# 9         0.163229               0.924643  ...        0     0     0
#
#    type_Movie  type_Music  type_ONA  type_OVA  type_Special  type_TV  \
# 0        True       False     False     False         False    False
# 1       False       False     False     False         False     True
# 2       False       False     False     False         False     True
# 3       False       False     False     False         False     True
# 4       False       False     False     False         False     True
# 5       False       False     False     False         False     True
# 6       False       False     False     False         False     True
# 7       False       False     False      True         False    False
# 8        True       False     False     False         False    False
# 9       False       False     False     False         False     True
#
#    type_Unknown
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
#
# [10 rows x 61 columns]

# %%
anime.columns
# Out:
# Index(['anime_id', 'name', 'episodes', 'rating', 'members', 'rating_count',
#        'user_avg_rating', 'user_median_rating', 'user_rating_std',
#        'popularity_percentile', 'Unnamed: 10', 'Action', 'Adventure', 'Cars',
#        'Comedy', 'Dementia', 'Demons', 'Drama', 'Ecchi', 'Fantasy', 'Game',
#        'Harem', 'Hentai', 'Historical', 'Horror', 'Josei', 'Kids', 'Magic',
#        'Martial Arts', 'Mecha', 'Military', 'Music', 'Mystery', 'Parody',
#        'Police', 'Psychological', 'Romance', 'Samurai', 'School', 'Sci-Fi',
#        'Seinen', 'Shoujo', 'Shoujo Ai', 'Shounen', 'Shounen Ai',
#        'Slice of Life', 'Space', 'Sports', 'Super Power', 'Supernatural',
#        'Thriller', 'Vampire', 'Yaoi', 'Yuri', 'type_Movie', 'type_Music',
#        'type_ONA', 'type_OVA', 'type_Special', 'type_TV', 'type_Unknown'],
#       dtype='object')

# %%
anime['Unnamed: 10']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 12289    0
# 12290    0
# 12291    0
# 12292    0
# 12293    0
# Name: Unnamed: 10, Length: 12294, dtype: int64

# %%
print(os.getcwd())
# Out:
# c:\Users\hu269\Desktop\cs 470\CS470

# %%
os.path.join("data/processed/","anime_features_normalized.csv")
# Out:
# 'data/processed/anime_features_normalized.csv'

# %%
set_1 = ['user_mean_rating', 'user_rating_count', 'engagement_percentile', 'genre_diversity', 'episodes', 'members', 'popularity_percentile', 'global_rating', 'Unnamed: 10', 'Action', 'Adventure', 'Cars', 'Comedy', 'Dementia', 'Demons', 'Drama', 'Ecchi', 'Fantasy', 'Game', 'Harem', 'Hentai', 'Historical', 'Horror', 'Josei', 'Kids', 'Magic', 'Martial Arts', 'Mecha', 'Military', 'Music', 'Mystery', 'Parody', 'Police', 'Psychological', 'Romance', 'Samurai', 'School', 'Sci-Fi', 'Seinen', 'Shoujo', 'Shoujo Ai', 'Shounen', 'Shounen Ai', 'Slice of Life', 'Space', 'Sports', 'Super Power', 'Supernatural', 'Thriller', 'Vampire', 'Yaoi', 'Yuri', 'type_Movie', 'type_Music', 'type_ONA', 'type_OVA', 'type_Special', 'type_TV', 'type_Unknown']
set_2 = ['user_mean_rating', 'user_median_rating_x', 'user_rating_count', 'user_rating_std_x', 'engagement_percentile', 'normalized_rating', 'genre_diversity', 'episodes', 'members', 'rating_count', 'user_avg_rating', 'user_median_rating_y', 'user_rating_std_y', 'popularity_percentile', 'Action', 'Adventure', 'Cars', 'Comedy', 'Dementia', 'Demons', 'Drama', 'Ecchi', 'Fantasy', 'Game', 'Harem', 'Hentai', 'Historical', 'Horror', 'Josei', 'Kids', 'Magic', 'Martial Arts', 'Mecha', 'Military', 'Music', 'Mystery', 'Parody', 'Police', 'Psychological', 'Romance', 'Samurai', 'School', 'Sci-Fi', 'Seinen', 'Shoujo', 'Shoujo Ai', 'Shounen', 'Shounen Ai', 'Slice of Life', 'Space', 'Sports', 'Super Power', 'Supernatural', 'Thriller', 'Vampire', 'Yaoi', 'Yuri', 'type_Movie', 'type_Music', 'type_ONA', 'type_OVA', 'type_Special', 'type_TV', 'type_Unknown', 'Action', 'Adventure', 'Cars', 'Comedy', 'Dementia', 'Demons', 'Drama', 'Ecchi', 'Fantasy', 'Game', 'Harem', 'Hentai', 'Historical', 'Horror', 'Josei', 'Kids', 'Magic', 'Martial Arts', 'Mecha', 'Military', 'Music', 'Mystery', 'Parody', 'Police', 'Psychological', 'Romance', 'Samurai', 'School', 'Sci-Fi', 'Seinen', 'Shoujo', 'Shoujo Ai', 'Shounen', 'Shounen Ai', 'Slice of Life', 'Space', 'Sports', 'Super Power', 'Supernatural', 'Thriller', 'Vampire', 'Yaoi', 'Yuri']

# Find elements in set_2 that are not in set_1
diff_2_1 = set(set_2) - set(set_1)
print("Elements in set_2 but not in set_1:")
print(sorted(diff_2_1))

# Find elements in set_1 that are not in set_2 
diff_1_2 = set(set_1) - set(set_2)
print("\nElements in set_1 but not in set_2:")
print(sorted(diff_1_2))

# Find duplicated elements in set_2
duplicates = [item for item in set_2 if set_2.count(item) > 1]
print("\nDuplicated elements in set_2:")
print(sorted(set(duplicates)))
# Out:
# Elements in set_2 but not in set_1:
# ['normalized_rating', 'rating_count', 'user_avg_rating', 'user_median_rating_x', 'user_median_rating_y', 'user_rating_std_x', 'user_rating_std_y']
#
# Elements in set_1 but not in set_2:
# ['Unnamed: 10', 'global_rating']
#
# Duplicated elements in set_2:
# ['Action', 'Adventure', 'Cars', 'Comedy', 'Dementia', 'Demons', 'Drama', 'Ecchi', 'Fantasy', 'Game', 'Harem', 'Hentai', 'Historical', 'Horror', 'Josei', 'Kids', 'Magic', 'Martial Arts', 'Mecha', 'Military', 'Music', 'Mystery', 'Parody', 'Police', 'Psychological', 'Romance', 'Samurai', 'School', 'Sci-Fi', 'Seinen', 'Shoujo', 'Shoujo Ai', 'Shounen', 'Shounen Ai', 'Slice of Life', 'Space', 'Sports', 'Super Power', 'Supernatural', 'Thriller', 'Vampire', 'Yaoi', 'Yuri']

# %%
os.getcwd()
# Out:
# 'c:\\Users\\hu269\\Desktop\\cs 470\\CS470'

# %%
train_enhanced = pd.read_csv(os.path.join('data/processed/','rating_train_v2_new.csv'))
test_enhanced = pd.read_csv(os.path.join('data/processed/','rating_test_v2_new.csv'))

rating_enhanced = pd.concat([train_enhanced,test_enhanced])
rating_enhanced.to_csv('data/processed/rating_enhanced_new.csv', index=False)

# %%
anime_df = pd.read_csv(os.path.join('data/processed/','anime_features_normalized_new.csv'))

# %%
anime_df.columns.tolist()
# Out:
# ['anime_id',
#  'name',
#  'episodes',
#  'global_rating',
#  'members',
#  'rating_count',
#  'user_avg_rating',
#  'user_median_rating',
#  'user_rating_std',
#  'popularity_percentile',
#  'Unnamed: 10',
#  'Action',
#  'Adventure',
#  'Cars',
#  'Comedy',
#  'Dementia',
#  'Demons',
#  'Drama',
#  'Ecchi',
#  'Fantasy',
#  'Game',
#  'Harem',
#  'Hentai',
#  'Historical',
#  'Horror',
#  'Josei',
#  'Kids',
#  'Magic',
#  'Martial Arts',
#  'Mecha',
#  'Military',
#  'Music',
#  'Mystery',
#  'Parody',
#  'Police',
#  'Psychological',
#  'Romance',
#  'Samurai',
#  'School',
#  'Sci-Fi',
#  'Seinen',
#  'Shoujo',
#  'Shoujo Ai',
#  'Shounen',
#  'Shounen Ai',
#  'Slice of Life',
#  'Space',
#  'Sports',
#  'Super Power',
#  'Supernatural',
#  'Thriller',
#  'Vampire',
#  'Yaoi',
#  'Yuri',
#  'type_Movie',
#  'type_Music',
#  'type_ONA',
#  'type_OVA',
#  'type_Special',
#  'type_TV',
#  'type_Unknown']

# %%
train_enhanced.columns.tolist()
# Out:
# ['user_id',
#  'anime_id',
#  'rating',
#  'user_mean_rating',
#  'user_median_rating',
#  'user_rating_count',
#  'user_rating_std',
#  'engagement_percentile',
#  'top_genres',
#  'genre_diversity']

# %%
test_enhanced.columns.tolist()
# Out:
# ['user_id',
#  'anime_id',
#  'rating',
#  'user_mean_rating',
#  'user_median_rating',
#  'user_rating_count',
#  'user_rating_std',
#  'engagement_percentile',
#  'genre_diversity',
#  'top_genres']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load the datasets
anime = pd.read_csv(os.path.join("data/raw/","anime.csv"))
ratings = pd.read_csv(os.path.join("data/raw/","rating.csv"))

plt.rcParams.update({
    'font.size': 12,
    'axes.titlesize': 16,
    'axes.labelsize': 14,
    'xtick.labelsize': 12,
    'ytick.labelsize': 12,
    'legend.fontsize': 12,
    'figure.titlesize': 18
})

# Load the datasets
anime = pd.read_csv(os.path.join("data/raw/","anime.csv"))
ratings = pd.read_csv(os.path.join("data/raw/","rating.csv"))

# --- 1. Top Anime Community Bar Plot ---
def plot_top_anime_by_members(anime_df, top_n=15):
    top_anime = anime_df.sort_values('members', ascending=False).head(top_n)
    
    plt.figure(figsize=(12,8))  # Increased figure size
    bars = sns.barplot(x='name', y='members', data=top_anime, palette='Paired')
    plt.xticks(rotation=90)
    plt.title('Top Anime Community', fontsize=20, fontweight='bold')  # Larger title
    plt.xlabel('Anime Name', fontsize=16)
    plt.ylabel('Total Member', fontsize=16)
    
    for bar, value in zip(bars.patches, top_anime['members']):
        bars.annotate(f'{int(value):,}', (bar.get_x() + bar.get_width()/2, bar.get_height()/2),
                      ha='center', va='center', fontsize=10, color='black',  # Increased annotation size
                      bbox=dict(boxstyle="round,pad=0.3", fc="orange", ec="black", lw=1))
    
    plt.tight_layout()
    plt.show()

# --- 2. Improved Anime Categories Donut Plot with better colors ---
def plot_category_distribution(anime_df):
    category_counts = anime_df['type'].value_counts()
    
    # Using a more visually appealing color palette
    colors = plt.cm.viridis(np.linspace(0, 1, len(category_counts)))
    
    plt.figure(figsize=(12,10))  # Increased figure size
    wedges, texts, autotexts = plt.pie(category_counts, labels=None, autopct='%1.2f%%', 
                                       startangle=140, wedgeprops=dict(width=0.5),
                                       colors=colors, textprops={'fontsize': 14})  # Increased text size
    
    # Enhance text visibility
    for autotext in autotexts:
        autotext.set_fontweight('bold')
        autotext.set_color('white')
    
    plt.title('Anime Categories Distribution', fontsize=22, fontweight='bold')  # Larger title
    
    # Create more visually attractive legend
    plt.legend(wedges, category_counts.index, title="Category Types", 
               loc="center left", bbox_to_anchor=(1, 0, 0.5, 1),
               fontsize=14, title_fontsize=18)  # Larger legend
    
    plt.tight_layout()
    plt.show()

# --- 3. Overall Anime Ratings Distribution ---
def plot_anime_ratings_distribution(anime_df):
    plt.figure(figsize=(12,7))  # Increased figure size
    sns.histplot(anime_df['rating'].dropna(), kde=True, color='gold', bins=20)
    plt.title("Anime's Average Ratings Distribution", fontsize=20, fontweight='bold')  # Larger title
    plt.xlabel('Rating', fontsize=16)
    plt.ylabel('Total', fontsize=16)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.tight_layout()
    plt.show()

# --- 4. Overall Users Anime Ratings Distribution ---
def plot_users_ratings_distribution(ratings_df):
    valid_ratings = ratings_df[ratings_df['rating'] != -1]
    plt.figure(figsize=(12,7))  # Increased figure size
    sns.histplot(valid_ratings['rating'], kde=True, color='gold', bins=20)
    plt.title("Users Anime Ratings Distribution", fontsize=20, fontweight='bold')  # Larger title
    plt.xlabel('Rating', fontsize=16)
    plt.ylabel('Total', fontsize=16)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.tight_layout()
    plt.show()

# --- 5. Consolidated Category-Wise Rating Distributions ---
def plot_all_category_distributions(anime_df, ratings_df):
    categories = anime_df['type'].dropna().unique()
    
    # Create a figure with two subplots
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(16, 14))  # Increased figure size
    
    # Color palette for different categories
    palette = plt.cm.tab10(np.linspace(0, 1, len(categories)))
    
    # First subplot: Anime's Average Ratings by Category
    for i, category in enumerate(categories):
        anime_filtered = anime_df[anime_df['type'] == category]
        if len(anime_filtered) > 0:
            sns.kdeplot(anime_filtered['rating'].dropna(), ax=ax1, 
                      label=f"{category} (n={len(anime_filtered)})", 
                      color=palette[i], fill=True, alpha=0.2)
    
    ax1.set_title("Anime's Average Ratings Distribution by Category", fontsize=20, fontweight='bold')  # Larger title
    ax1.set_xlabel('Rating', fontsize=16)
    ax1.set_ylabel('Density', fontsize=16)
    ax1.legend(title="Category", fontsize=14, title_fontsize=16)  # Larger legend
    ax1.tick_params(axis='both', which='major', labelsize=14)  # Larger tick labels
    ax1.grid(True, linestyle='--', alpha=0.7)
    
    # Second subplot: Users' Ratings by Category
    for i, category in enumerate(categories):
        anime_filtered = anime_df[anime_df['type'] == category]
        merged = pd.merge(ratings_df, anime_filtered[['anime_id', 'name']], on='anime_id')
        valid_user_ratings = merged[merged['rating'] != -1]
        
        if len(valid_user_ratings) > 0:
            sns.kdeplot(valid_user_ratings['rating'], ax=ax2, 
                       label=f"{category} (n={len(valid_user_ratings)})", 
                       color=palette[i], fill=True, alpha=0.2)
    
    ax2.set_title("Users' Anime Ratings Distribution by Category", fontsize=20, fontweight='bold')  # Larger title
    ax2.set_xlabel('Rating', fontsize=16)
    ax2.set_ylabel('Density', fontsize=16)
    ax2.legend(title="Category", fontsize=14, title_fontsize=16)  # Larger legend
    ax2.tick_params(axis='both', which='major', labelsize=14)  # Larger tick labels
    ax2.grid(True, linestyle='--', alpha=0.7)
    
    plt.tight_layout()
    plt.show()

# %%
def plot_top_anime_by_members(anime_df, top_n=15):
    top_anime = anime_df.sort_values('members', ascending=False).head(top_n)
    
    plt.figure(figsize=(10,6))
    bars = sns.barplot(x='name', y='members', data=top_anime, palette='Paired')
    plt.xticks(rotation=90)
    plt.title('Top Anime Community')
    plt.xlabel('Anime Name')
    plt.ylabel('Total Member')
    
    for bar, value in zip(bars.patches, top_anime['members']):
        bars.annotate(f'{int(value):,}', (bar.get_x() + bar.get_width()/2, bar.get_height()/2),
                      ha='center', va='center', fontsize=8, color='black',
                      bbox=dict(boxstyle="round,pad=0.3", fc="orange", ec="black", lw=1))
    
    plt.tight_layout()
    plt.show()

# --- 2. Improved Anime Categories Donut Plot with better colors ---
def plot_category_distribution(anime_df):
    category_counts = anime_df['type'].value_counts()
    
    # Using a more visually appealing color palette
    colors = plt.cm.viridis(np.linspace(0, 1, len(category_counts)))
    
    plt.figure(figsize=(10,8))
    wedges, texts, autotexts = plt.pie(category_counts, labels=None, autopct='%1.2f%%', 
                                       startangle=140, wedgeprops=dict(width=0.5),
                                       colors=colors, textprops={'fontsize': 12})
    
    # Enhance text visibility
    for autotext in autotexts:
        autotext.set_fontweight('bold')
        autotext.set_color('white')
    
    plt.title('Anime Categories Distribution', fontsize=16, fontweight='bold')
    
    # Create more visually attractive legend
    plt.legend(wedges, category_counts.index, title="Category Types", 
               loc="center left", bbox_to_anchor=(1, 0, 0.5, 1),
               fontsize=12, title_fontsize=14)
    
    plt.tight_layout()
    plt.show()

# --- 3. Overall Anime Ratings Distribution ---
def plot_anime_ratings_distribution(anime_df):
    plt.figure(figsize=(10,5))
    sns.histplot(anime_df['rating'].dropna(), kde=True, color='gold', bins=20)
    plt.title("Anime's Average Ratings Distribution")
    plt.xlabel('Rating')
    plt.ylabel('Total')
    plt.show()

# --- 4. Overall Users Anime Ratings Distribution ---
def plot_users_ratings_distribution(ratings_df):
    valid_ratings = ratings_df[ratings_df['rating'] != -1]
    plt.figure(figsize=(10,5))
    sns.histplot(valid_ratings['rating'], kde=True, color='gold', bins=20)
    plt.title("Users Anime Ratings Distribution")
    plt.xlabel('Rating')
    plt.ylabel('Total')
    plt.show()

# --- 5. Consolidated Category-Wise Rating Distributions ---
def plot_all_category_distributions(anime_df, ratings_df):
    categories = anime_df['type'].dropna().unique()
    
    # Create a figure with two subplots
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 12))
    
    # Color palette for different categories
    palette = plt.cm.tab10(np.linspace(0, 1, len(categories)))
    
    # First subplot: Anime's Average Ratings by Category
    for i, category in enumerate(categories):
        anime_filtered = anime_df[anime_df['type'] == category]
        if len(anime_filtered) > 0:
            sns.kdeplot(anime_filtered['rating'].dropna(), ax=ax1, 
                      label=f"{category} (n={len(anime_filtered)})", 
                      color=palette[i], fill=True, alpha=0.2)
    
    ax1.set_title("Anime's Average Ratings Distribution by Category", fontsize=14, fontweight='bold')
    ax1.set_xlabel('Rating', fontsize=12)
    ax1.set_ylabel('Density', fontsize=12)
    ax1.legend(title="Category", fontsize=10)
    ax1.grid(True, linestyle='--', alpha=0.7)
    
    # Second subplot: Users' Ratings by Category
    for i, category in enumerate(categories):
        anime_filtered = anime_df[anime_df['type'] == category]
        merged = pd.merge(ratings_df, anime_filtered[['anime_id', 'name']], on='anime_id')
        valid_user_ratings = merged[merged['rating'] != -1]
        
        if len(valid_user_ratings) > 0:
            sns.kdeplot(valid_user_ratings['rating'], ax=ax2, 
                       label=f"{category} (n={len(valid_user_ratings)})", 
                       color=palette[i], fill=True, alpha=0.2)
    
    ax2.set_title("Users' Anime Ratings Distribution by Category", fontsize=14, fontweight='bold')
    ax2.set_xlabel('Rating', fontsize=12)
    ax2.set_ylabel('Density', fontsize=12)
    ax2.legend(title="Category", fontsize=10)
    ax2.grid(True, linestyle='--', alpha=0.7)
    
    plt.tight_layout()
    plt.show()

# %%
plot_top_anime_by_members(anime)
plot_category_distribution(anime)
plot_anime_ratings_distribution(anime)
plot_users_ratings_distribution(ratings)
plot_all_category_distributions(anime, ratings)
# Out:
# C:\Users\hu269\AppData\Local\Temp\ipykernel_3880\1659594084.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bars = sns.barplot(x='name', y='members', data=top_anime, palette='Paired')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

corr_matrix = pd.read_csv(os.path.join("src/analysis/","feature_correlation_matrix.csv"))

# Assuming your correlation matrix is stored in a DataFrame called 'corr_matrix'
# If you have the raw data instead, you would first calculate the correlation:
# corr_matrix = your_dataframe.corr()

# Example of how to create a filtered correlation matrix
def filter_correlation_matrix(corr_matrix, threshold=0.3):
    """
    Filter correlation matrix to show only correlations above a certain threshold.
    
    Parameters:
    -----------
    corr_matrix : pandas.DataFrame
        The correlation matrix
    threshold : float
        The absolute threshold value (correlations with absolute value below this will be filtered out)
        
    Returns:
    --------
    pandas.DataFrame
        Filtered correlation matrix
    """
    # Make a copy to avoid modifying the original
    filtered_corr = corr_matrix.copy()
    
    # Replace correlations below threshold with NaN
    filtered_corr = filtered_corr.where(np.abs(filtered_corr) >= threshold, np.nan)
    
    # Keep the diagonal values (correlation of variables with themselves)
    np.fill_diagonal(filtered_corr.values, 1)
    
    return filtered_corr

# Example usage:
filtered_corr = filter_correlation_matrix(corr_matrix, threshold=0.3)

# Visualize the filtered correlation matrix
def plot_filtered_correlation(corr_matrix, threshold=0.3, figsize=(12, 10)):
    """
    Plot a filtered correlation matrix as a heatmap.
    """
    filtered = filter_correlation_matrix(corr_matrix, threshold)
    
    # Create a mask for the upper triangle
    mask = np.triu(np.ones_like(filtered, dtype=bool))
    
    # Set up the matplotlib figure
    plt.figure(figsize=figsize)
    
    # Generate a custom diverging colormap
    cmap = sns.diverging_palette(230, 20, as_cmap=True)
    
    # Draw the heatmap with the mask and correct aspect ratio
    sns.heatmap(filtered, mask=mask, cmap=cmap, vmax=1, vmin=-1, center=0,
                square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)
    
    plt.title(f'Correlation Matrix (|r| >= {threshold})')
    plt.tight_layout()
    plt.show()

# Example usage:
plot_filtered_correlation(corr_matrix, threshold=0.3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 42
#      39     return filtered_corr
#      41 # Example usage:
# ---> 42 filtered_corr = filter_correlation_matrix(corr_matrix, threshold=0.3)
#      44 # Visualize the filtered correlation matrix
#      45 def plot_filtered_correlation(corr_matrix, threshold=0.3, figsize=(12, 10)):
#
# Cell In[2], line 34, in filter_correlation_matrix(corr_matrix, threshold)
#      31 filtered_corr = corr_matrix.copy()
#      33 # Replace correlations below threshold with NaN
# ---> 34 filtered_corr = filtered_corr.where(np.abs(filtered_corr) >= threshold, np.nan)
#      36 # Keep the diagonal values (correlation of variables with themselves)
#      37 np.fill_diagonal(filtered_corr.values, 1)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\generic.py:2171, in NDFrame.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2167 @final
#    2168 def __array_ufunc__(
#    2169     self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2170 ):
# -> 2171     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\arraylike.py:276, in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     273 kwargs = _standardize_out_kwarg(**kwargs)
#     275 # for binary ops, use our custom dunder methods
# --> 276 result = maybe_dispatch_ufunc_to_dunder_op(self, ufunc, method, *inputs, **kwargs)
#     277 if result is not NotImplemented:
#     278     return result
#
# File ops_dispatch.pyx:105, in pandas._libs.ops_dispatch.maybe_dispatch_ufunc_to_dunder_op()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\generic.py:1726, in NDFrame.__abs__(self)
#    1724 @final
#    1725 def __abs__(self) -> Self:
# -> 1726     return self.abs()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\generic.py:1719, in NDFrame.abs(self)
#    1651 @final
#    1652 def abs(self) -> Self:
#    1653     """
#    1654     Return a Series/DataFrame with absolute numeric value of each element.
#    1655
#    (...)   1717     3    7   40  -50
#    1718     """
# -> 1719     res_mgr = self._mgr.apply(np.abs)
#    1720     return self._constructor_from_mgr(res_mgr, axes=res_mgr.axes).__finalize__(
#    1721         self, name="abs"
#    1722     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\internals\managers.py:361, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     358             kwargs[k] = obj[b.mgr_locs.indexer]
#     360 if callable(f):
# --> 361     applied = b.apply(f, **kwargs)
#     362 else:
#     363     applied = getattr(b, f)(**kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\internals\blocks.py:393, in Block.apply(self, func, **kwargs)
#     387 @final
#     388 def apply(self, func, **kwargs) -> list[Block]:
#     389     """
#     390     apply the function to my values; return a block if we are not
#     391     one
#     392     """
# --> 393     result = func(self.values, **kwargs)
#     395     result = maybe_coerce_values(result)
#     396     return self._split_op_result(result)
#
# TypeError: bad operand type for abs(): 'str'
